# %%
from pathlib import Path
import pandas as pd

ROOT = Path.cwd().parent
DATA = ROOT / "data" / "ethereum_labelled_addresses"

eth_labbeled = pd.read_csv(DATA / "labelled-ethereum-addresses/eth_addresses.csv")

# %%
eth_labbeled.shape
# Out:
# (19138, 12)

# %%
eth_labbeled.head(50)
# Out:
#                                        Address  \
# 0   0x8ab7404063ec4dbcfd4598215992dc3f8ec853d7
# 1   0x1c74cff0376fb4031cd7492cd6db2d66c3f2c6b9
# 2   0x06af07097c9eeb7fd685c692751d5c66db49c215
# 3   0xc00e94cb662c3520282e6f5717214004a7f26888
# 4   0xb3319f5d18bc0d84dd1b4825dcde5d5f7266d407
# 5   0x158079ee67fce2f58472a96584a73c7ab9ac95c1
# 6   0x6c8c6b02e7b2be14d4fa6022dfd6d75921d90e4e
# 7   0x5d3a536e4d6dbd6114cc1ead35777bab948e3643
# 8   0x4ddc2d193948926d02f9b1fe9e1daa0718270ed5
# 9   0xf5dce57282a584d2746faf1593d3121fcac444dc
# 10  0x39aa39c021dfbae8fac545936693ac917d5e7563
# 11  0xf650c3d88d12db855b8bf7d11be6c55a4e07dcc9
# 12  0xc11b1268c1a384e55c48c2391d8d480264a3a7f4
# 13  0x6b175474e89094c44da98b954eedeac495271d0f
# 14  0x9b869c2eaae08136c43d824ea75a2f376f1aa983
# 15  0x431ad2ff6a9c365805ebad47ee021148d6f7dbe0
# 16  0x59459a7fdf11a341bb14413cca51850f072901cc
# 17  0x80fb784b7ed66730e8b1dbd9820afd29931aab03
# 18  0x493c57c4763932315a328269e1adad09653b9081
# ...

# %%
eth_labbeled.dtypes
# Out:
# Address          str
# Name             str
# Account Type     str
# Contract Type    str
# Entity           str
# Label            str
# Tags             str
# Unnamed: 7       str
# Unnamed: 8       str
# Unnamed: 9       str
# Unnamed: 10      str
# Unnamed: 11      str
# dtype: object

# %% [markdown]
# **Missing Values:**

# %%
eth_labbeled.isna().sum().sort_values(ascending=False).head(15)
# Out:
# Unnamed: 11      19137
# Unnamed: 10      19114
# Unnamed: 9       18997
# Unnamed: 8       18353
# Entity           17492
# Contract Type    15809
# Unnamed: 7       14535
# Name               170
# Tags                 3
# Account Type         3
# Address              0
# Label                0
# dtype: int64

# %%
eth_labbeled.isna().sum().sum()
# Out:
# np.int64(123613)

# %% [markdown]
# **Dublicates:**

# %%
eth_labbeled.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Target Distribution:**

# %%
eth_labbeled["Label"].value_counts()
# Out:
# Label
# Legit    13925
# Dodgy     5212
# Name: count, dtype: int64

# %%
eth_labbeled["Label"].value_counts(normalize=True) * 100
# Out:
# Label
# Legit    72.764801
# Dodgy    27.235199
# Name: proportion, dtype: float64

# %%
eth_labbeled["Label"].unique()
# Out:
# <StringArray>
# ['Legit', 'Label', 'Dodgy']
# Length: 3, dtype: str

# %%
eth_labbeled[eth_labbeled["Label"] == "Label"]
# Out:
#       Address  Name  Account Type  Contract Type  Entity  Label  Tags  \
# 1127  Address  Name  Account Type  Contract Type  Entity  Label  Tags
#
#      Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11
# 1127        NaN        NaN        NaN         NaN         NaN

# %%
eth_labbeled = eth_labbeled[eth_labbeled["Label"] != "Label"]

# %%
eth_labbeled[eth_labbeled["Label"] == "Label"]
# Out:
# Empty DataFrame
# Columns: [Address, Name, Account Type, Contract Type, Entity, Label, Tags, Unnamed: 7, Unnamed: 8, Unnamed: 9, Unnamed: 10, Unnamed: 11]
# Index: []
