# %%
import pandas as pd
import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("Project root:", project_root)
print("src exists:", (project_root / "src").exists())
# Out:
# Project root: c:\University\Year4\Thesis\AML-Thesis
# src exists: True

# %%
from src.data_loader import load_transactions_graph_simple

X_train, X_test, y_train, y_test, train_time, test_time = load_transactions_graph_simple()

assert "Time step" not in X_train.columns
assert "Time step" not in X_test.columns
assert len(test_time) == len(y_test) == len(X_test)
assert len(train_time) == len(y_train) == len(X_train)
assert max(train_time) < min(test_time), "Time boundary not clean!"

print(f"Train steps: {sorted(train_time.unique())[0]}–{sorted(train_time.unique())[-1]} ({len(train_time)} rows)")
print(f"Test steps:  {sorted(test_time.unique())[0]}–{sorted(test_time.unique())[-1]} ({len(test_time)} rows)")
print(f"Illicit rate — train: {y_train.mean():.4f}, test: {y_test.mean():.4f}")
# Out:
# Saved cleaned dataset to: C:\University\Year4\Thesis\AML-Thesis\data\clean_datasets\elliptic_plus_plus\transactions_graph_clean.csv
# Train steps: 1–39 (156461 rows)
# Test steps:  40–49 (46343 rows)
# Illicit rate — train: 2.3544, test: 2.2969

# %%
from src.data_loader import _load_raw_elliptic_transactions_combined

trn_combined = _load_raw_elliptic_transactions_combined()
trn_combined
# Out:
#              txId  Time step  Local_feature_1  Local_feature_2  \
# 0            3321          1        -0.169615        -0.184668
# 1           11108          1        -0.137586        -0.184668
# 2           51816          1        -0.170103        -0.184668
# 3           68869          1        -0.114267        -0.184668
# 4           89273          1         5.202107        -0.210553
# ...           ...        ...              ...              ...
# 203764  158304003         49        -0.165622        -0.139563
# 203765  158303998         49        -0.167040        -0.139563
# 203766  158303966         49        -0.167040        -0.139563
# 203767  161526077         49        -0.172212        -0.139573
# 203768  194103537         49        -0.172212        -0.139573
#
#         Local_feature_3  Local_feature_4  Local_feature_5  Local_feature_6  \
# 0             -1.201369        -0.121970        -0.043875        -0.113002
# ...

# %%
from src.data_loader import _load_preprocessed_elliptic_graph

trn_graph_cleaned = _load_preprocessed_elliptic_graph()
trn_graph_cleaned
# Out:
#              txId  Time step  Local_feature_1  Local_feature_2  \
# 0            3321          1        -0.169615        -0.184668
# 1           11108          1        -0.137586        -0.184668
# 2           51816          1        -0.170103        -0.184668
# 3           68869          1        -0.114267        -0.184668
# 4           89273          1         5.202107        -0.210553
# ...           ...        ...              ...              ...
# 202799  194747812         49         0.558398        -0.198956
# 202800  194747925         49         0.547658        -0.198956
# 202801  194748063         49         0.543600        -0.198853
# 202802  194748070         49         0.537760        -0.198853
# 202803  194835939         49        -0.170463        -0.152788
#
#         Local_feature_3  Local_feature_4  Local_feature_5  Local_feature_6  \
# 0             -1.201369        -0.121970        -0.043875        -0.113002
# ...

# %%
trn_graph_cleaned.isna().sum()
# Out:
# txId               0
# Time step          0
# Local_feature_1    0
# Local_feature_2    0
# Local_feature_3    0
#                   ..
# out_BTC_max        0
# out_BTC_mean       0
# out_BTC_median     0
# out_BTC_total      0
# class              0
# Length: 185, dtype: int64

# %%
print((trn_graph_cleaned["class"] == 3).any())
# Out:
# True

# %%
print((trn_graph_cleaned["class"] == 2).any())
# Out:
# False

# %%
print(trn_graph_cleaned.duplicated().sum())
# Out:
# 0

# %%
# Out:
# Train steps: 1–39 (156461 rows)
# Test steps:  40–49 (46343 rows)
# Illicit rate — train: 2.3544, test: 2.2969
